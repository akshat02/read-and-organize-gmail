# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'svg'
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Citi_Gmail.csv')
df.head()
# Out:
#               Date  Amount                 Place  \
# 0  9/15/2019 19:07   328.0    KIRTI SUPER MARKET
# 1  9/15/2019 14:25     1.0     CLOUD.GOOGLE.COM/
# 2  9/15/2019 14:25     1.0     CLOUD.GOOGLE.COM/
# 3  9/15/2019 11:08   158.0  AMAZON PAY INDIA PRI
# 4  9/13/2019 20:28  1502.0          LIFE STYLE .
#
#                                              Snippet
# 0  Your Citi Credit Card Transaction Details. You...
# 1  Your Citi Credit Card Transaction Details. You...
# 2  Your Citi Credit Card Transaction Details. You...
# 3  Your Citi Credit Card Transaction Details. You...
# 4  Your Citi Credit Card Transaction Details. You...

# %%
print(df.describe())
# Out:
#             Amount
# count   100.000000
# mean    471.098700
# std     810.113665
# min       1.000000
# 25%     119.750000
# 50%     179.500000
# 75%     401.752500
# max    6048.000000

# %%
features = ['Date', 'Amount']

# %%
df[features].hist(figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000208B708E240>]],
#       dtype=object)

# %%
df[features].plot(kind='density', subplots=True, layout=(1, 2), 
                  sharex=False, figsize=(10, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000208B7398D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208B74126A0>]],
#       dtype=object)

# %%
sns.distplot(df['Amount']);

# %%
sns.boxplot(x = 'Amount', data = df)

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 5))
sns.boxplot(data=df['Amount'], ax=axes[0]);
sns.violinplot(data=df['Amount'], ax=axes[1]);
